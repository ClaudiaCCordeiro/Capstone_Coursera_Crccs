# %% [markdown]
# # Final Capstone

# %% [markdown]
# ## Solving environment

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

import json

import os
import branca
import io
#import plotly.graph_objs as go 
#from plotly.offline import plot

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
#Importing and reading de geolocalization data
url1 = 'https://raw.githubusercontent.com/ClaudiaCCordeiro/Capstone_Coursera_Crccs/master/saudemunicipalestadual.geojson'
with open('saudemunicipalestadual.geojson', encoding='utf-8') as json_data:
    recife_data = json.load(json_data)
recife_data
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-42d137f23d3f> in <module>
#       1 #Importing and reading de geolocalization data
#       2 url1 = 'https://raw.githubusercontent.com/ClaudiaCCordeiro/Capstone_Coursera_Crccs/master/saudemunicipalestadual.geojson'
# ----> 3 with open(url1, encoding='utf-8') as json_data:
#       4     recife_data = json.load(json_data)
#       5 recife_data
#
# OSError: [Errno 22] Invalid argument: 'https://raw.githubusercontent.com/ClaudiaCCordeiro/Capstone_Coursera_Crccs/master/saudemunicipalestadual.geojson'

# %%
#Importing and reading de geolocalization data
url1 = 'https://raw.githubusercontent.com/ClaudiaCCordeiro/Capstone_Coursera_Crccs/master/bairros.geojson'
with open('bairros.geojson', encoding='utf-8') as json_data:
    recife_data = json.load(json_data)
recife_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 0,
#    'properties': {'bairro_codigo': 728,
#     'bairro_nome_ca': 'CIDADE UNIVERSITARIA',
#     'rpa': 4,
#     'microrregiao': 3,
#     'bairro_nome': 'Cidade Universitária'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-34.944159036934906, -8.04984630501871],
#       [-34.94419151990481, -8.050204895163283],
#       [-34.94419743895523, -8.05027023442114],
#       [-34.94431120757218, -8.051585950694623],
#       [-34.94431131783154, -8.051594802624184],
#       [-34.944311753991926, -8.051629758340791],
#       [-34.942945018203595, -8.052009873555523],
#       [-34.94315216357978, -8.053576771888464],
#       [-34.94315812584044, -8.053621878336617],
#       [-34.94601997813883, -8.052832348362527],
#       [-34.94621711962542, -8.052791992945341],
#       [-34.94623791711754, -8.052970794599196],
#       [-34.946288170803314, -8.053987267004896],
# ...
