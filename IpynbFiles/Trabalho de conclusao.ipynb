# %% [markdown]
# # Final Capstone

# %% [markdown]
# ## Solving environment

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

import json

import os
import branca
import io
#import plotly.graph_objs as go 
#from plotly.offline import plot

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
#Importing and reading de geolocalization data
url1 = 'https://raw.githubusercontent.com/ClaudiaCCordeiro/Capstone_Coursera_Crccs/master/saudemunicipalestadual.geojson'
with open('saudemunicipalestadual.geojson', encoding='utf-8') as json_data:
    unidadesRecife_data = json.load(json_data)
unidadesRecife_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 0,
#    'properties': {'NMUNIDAD': 'ALBERGUE TERAPEUTICO CASA MEIO DO CAMINHO ANTONIO N',
#     'NMENDUNID': 'RUA CELIO TAVARES, 87 IMBIRIBEIRA',
#     'NMPATRIM': None,
#     'CDTIPO': 'Albergue Terapeutica'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-34.917021587976365, -8.091571337102636],
#       [-34.916867715294, -8.091632331533736],
#       [-34.91697678711308, -8.0918776347906],
#       [-34.91712948539789, -8.09181900993758],
#       [-34.917021587976365, -8.091571337102636]]]}},
#   {'type': 'Feature',
#    'id': 1,
#    'properties': {'NMUNIDAD': 'UNIDADE DE SAUDE DA FAMILIA SAO JOSE DO COQUE',
#     'NMENDUNID': 'AVENIDA CENTRAL S/N',
#     'NMPATRIM': 'PROPRIO',
#     'CDTIPO': 'USF'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-34.896339307620394, -8.072948893118792],
#       [-34.8963902908527, -8.072752290365308],
# ...

# %%
unidades_data = unidadesRecife_data  ['features']
unidades_data [0]
# Out:
# {'type': 'Feature',
#  'id': 0,
#  'properties': {'NMUNIDAD': 'ALBERGUE TERAPEUTICO CASA MEIO DO CAMINHO ANTONIO N',
#   'NMENDUNID': 'RUA CELIO TAVARES, 87 IMBIRIBEIRA',
#   'NMPATRIM': None,
#   'CDTIPO': 'Albergue Terapeutica'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-34.917021587976365, -8.091571337102636],
#     [-34.916867715294, -8.091632331533736],
#     [-34.91697678711308, -8.0918776347906],
#     [-34.91712948539789, -8.09181900993758],
#     [-34.917021587976365, -8.091571337102636]]]}}

# %%
# define the dataframe columns
column_names = ['NomeUnidade', 'Adress', 'TipoPatrimonio', 'TipoUnidade', 'Lat','Lgt'] 

# instantiate the dataframe
UnidadesSaude = pd.DataFrame(columns=column_names)
UnidadesSaude
# Out:
# Empty DataFrame
# Columns: [NomeUnidade, Adress, TipoPatrimonio, TipoUnidade, Lat, Lgt]
# Index: []

# %%
for data in unidades_data:
    
    NomeUnidade =  data['properties']['NMUNIDAD'] 
    Adress = data['properties']['NMENDUNID']
    TipoPatrimonio = data['properties']['NMPATRIM']
    TipoUnidade = data['properties']['CDTIPO']
       
        
    unidades_latlon = data['geometry']['coordinates']
    unidades_lat = unidades_latlon[0][0][1]
    unidades_lon = unidades_latlon[0][0][0]
    
    if isinstance(unidades_lat, list):
        unidades_lat = unidades_lat[1]
        unidades_lon = unidades_lon[0]
        print(Unidade_name, unidades_lat, unidades_lon)
    
    
    
    UnidadesSaude = UnidadesSaude.append({'NomeUnidade',
                                          'Adress',
                                          'TipoPatrimonio',
                                          'TipoUnidade',
                                          'Lat': unidades_lat,
                                          'Lgt': unidades_lon}, ignore_index=True)
    
#UnidadesSaude.drop_duplicates(['Neighborhood'], inplace=True)
#neighborhoods = pd.merge( neighborhoods,df_neighborhood, on='Neighborhood', how='left')
UnidadesSaude.head()
# Out:
#   File "<ipython-input-29-ef6c05355563>", line 24
#     'Lat': unidades_lat,
#          ^
# SyntaxError: invalid syntax
